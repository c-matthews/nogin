# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %%
X = sio.loadmat('test.mat')

# %%
X
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Wed Feb 13 14:17:50 2019',
#  '__version__': '1.0',
#  '__globals__': [],
#  'E': array([[-2.70325879e+02, -3.56867544e+02, -5.18264612e+02, ...,
#          -7.76208942e+01, -2.94523302e+02, -2.03302562e+02],
#         [ 1.92198420e-01,  1.92198420e-01,  1.92198420e-01, ...,
#           1.92198420e-01,  1.92198420e-01,  1.92198420e-01]]),
#  'N': array([[50000]]),
#  'T': array([[20.89268422]]),
#  'date': array(['2019-02-13 14:17:49'], dtype='<U19'),
#  'dt': array([[0.03]]),
#  'g': array([[1.]]),
#  'ig': array(['sgld'], dtype='<U4'),
#  'model': array(['gmean'], dtype='<U5'),
#  'k': array([[3]]),
#  'dataset': array(['data/gmean/data.mat'], dtype='<U19'),
#  'ofreq': array([[1]]),
#  'acc': array([[0.]]),
#  'cfac': array([[1]]),
#  'Xmean': array([[-0.03173562]]),
#  'Xcov': array([[0.09331908]]),
#  'X': array([[-0.10934367,  0.19195227,  0.10211594, ..., -0.27258494,
#          -0.02319293,  0.0827024 ]]),
# ...

# %%
plt.plot(X['X'].ravel())
plt.show()

# %%
aa,bb = np.histogram( X['X'].ravel(),bins=50 )
midb = (bb[1:]+bb[:-1])/2
plt.plot(midb,aa)
plt.show()

# %%
xx= X['X'].ravel()
print(xx.shape)
print( [np.mean(xx), np.var(xx)])
# Out:
# (50000,)
# [-0.03322650760671589, 0.09288996969060609]

# %%
print( [np.mean(xx), np.var(xx)])
# Out:
# [-0.03322650760671589, 0.09288996969060609]

# %%
acf = [] 
xx=xx-np.mean(xx)
sig2 = np.mean(xx**2)
for ii in range(100):
    acf+= [ np.mean( xx[ii+1:] * xx[:-ii-1])/ sig2]

# %%
plt.plot(acf)

# %%
1000 / (1.3**22)
# Out:
# 3.1134812112267327
