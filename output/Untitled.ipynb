# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %%
X = sio.loadmat('test.mat')

# %%
X
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Tue Feb 12 22:11:10 2019',
#  '__version__': '1.0',
#  '__globals__': [],
#  'E': array([[-4.00736283e+02, -1.81005562e+02, -1.01182344e+03, ...,
#          -5.95285318e+02, -6.30557726e+02, -3.38835044e+02],
#         [ 3.63020386e-01,  3.63020386e-01,  3.63020386e-01, ...,
#           3.63020386e-01,  3.63020386e-01,  3.63020386e-01]]),
#  'N': array([[50000]]),
#  'T': array([[29.11188197]]),
#  'date': array(['2019-02-12 22:11:10'], dtype='<U19'),
#  'dt': array([[0.01]]),
#  'g': array([[1.]]),
#  'ig': array(['msgld'], dtype='<U5'),
#  'model': array(['gmean'], dtype='<U5'),
#  'k': array([[10]]),
#  'dataset': array(['data/gmean/data.mat'], dtype='<U19'),
#  'ofreq': array([[1]]),
#  'acc': array([[0.]]),
#  'cfac': array([[1]]),
#  'Xmean': array([[-0.03242416]]),
#  'Xcov': array([[0.00228034]]),
#  'X': array([[ 0.03556991,  0.02804334, -0.00538397, ..., -0.0264993 ,
#          -0.00916779, -0.01124745]])}

# %%
plt.plot(X['X'].ravel())
plt.show()

# %%
aa,bb = np.histogram( X['X'].ravel(),bins=50 )
midb = (bb[1:]+bb[:-1])/2
plt.plot(midb,aa)
plt.show()

# %%
xx= X['X'].ravel()
print(xx.shape)
print( [np.mean(xx), np.var(xx)])
# Out:
# (50000,)
# [-0.03208681218789567, 0.002273702631805346]

# %%
print( [np.mean(xx), np.var(xx)])
# Out:
# [-0.030413984836336866, 0.002676800172527948]

# %%
acf = [] 
xx=xx-np.mean(xx)
sig2 = np.mean(xx**2)
for ii in range(100):
    acf+= [ np.mean( xx[ii+1:] * xx[:-ii-1])/ sig2]

# %%
plt.plot(acf)
